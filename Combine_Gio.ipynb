# %%
# Dependencies
    #import pandas as pd
#Setting Datasets
#df = "Resources/OL2010_2013.csv"
    #combine1 = "Resources/OL2014_2015.csv"
    #combine2 = "Resources/TE2010_2015.csv"
#Loading into DataFrame
#df = pd.read_csv(df, encoding="utf-8")
    #combine1 = pd.read_csv(combine1, encoding="utf-8")
    #combine2 = pd.read_csv(combine2, encoding="utf-8")

import pandas as pd

df = "Resources/OL2010_2013.csv"
df = pd.read_csv(df, encoding="utf-8")

filenames = ["Resources/OL2014_2015.csv", "Resources/TE2010_2015.csv", 
             "Resources/WR2010_2013.csv", "Resources/WR2014_2015.csv"]

for filename in filenames:
    df = df.append(pd.read_csv(filename), ignore_index=True)

df['Pos'] = df['Pos'].replace({'OG': 'OL', 'OT': 'OL'})

df
# Out:
#      Rk  Year               Player Pos   AV            School        College  \
# 0     1  2013        Brian Winters  OL   27        Kent State            NaN
# 1     2  2013     Brennan Williams  OL  NaN    North Carolina  College Stats
# 2     3  2013          John Wetzel  OL   11    Boston College            NaN
# 3     4  2013         Jason Weaver  OL  NaN     Southern Miss            NaN
# 4     5  2013       Menelik Watson  OL   12     Florida State            NaN
# 5     6  2013         Earl Watford  OL   12     James Madison            NaN
# 6     7  2013       Chance Warmack  OL   23           Alabama  College Stats
# 7     8  2013        Larry Warford  OL   48          Kentucky            NaN
# 8     9  2013         Ricky Wagner  OL   38         Wisconsin            NaN
# 9    10  2013         J.C. Tretter  OL   20           Cornell            NaN
# 10   11  2013        Hugh Thornton  OL   17          Illinois  College Stats
# 11   12  2013        Dallas Thomas  OL   12         Tennessee            NaN
# 12   13  2013   David Quessenberry  OL    0    San Jose State            NaN
# 13   14  2013          Justin Pugh  OL   30          Syracuse  College Stats
# 14   15  2013      Vinston Painter  OL    0     Virginia Tech            NaN
# 15   16  2013         Xavier Nixon  OL    2           Florida            NaN
# 16   17  2013         Jordan Mills  OL   41    Louisiana Tech            NaN
# 17   18  2013      Stephane Milhim  OL  NaN     Massachusetts  College Stats
# 18   19  2013       Luke Marquardt  OL  NaN     Azusa Pacific            NaN
# 19   20  2013           Lamar Mady  OL    0  Youngstown State            NaN
# 20   21  2013            Kyle Long  OL   43            Oregon            NaN
# 21   22  2013       Edmund Kugbila  OL  NaN    Valdosta State            NaN
# 22   23  2013        Oscar Johnson  OL  NaN    Louisiana Tech            NaN
# 23   24  2013         Lane Johnson  OL   47          Oklahoma            NaN
# 24   25  2013  Jamaal Johnson-Webb  OL  NaN       Alabama A&M            NaN
# 25   26  2013         Luke Joeckel  OL   23         Texas A&M  College Stats
# 26   27  2013          Eric Herman  OL  NaN              Ohio  College Stats
# 27   28  2013     Tanner Hawkinson  OL    0            Kansas            NaN
# 28   29  2013       Garrett Gilkey  OL    2     Chadron State            NaN
# 29   30  2013        Rogers Gaines  OL  NaN   Tennessee State            NaN
# ..   ..   ...                  ...  ..  ...               ...            ...
# 609  65  2014          Allen Hurns  WR   22        Miami (FL)  College Stats
# 610  66  2014            Josh Huff  WR    6            Oregon  College Stats
# 611  67  2014         Cody Hoffman  WR  NaN               BYU  College Stats
# 612  68  2014        Robert Herron  WR    0           Wyoming  College Stats
# 613  69  2014           Matt Hazel  WR    0  Coastal Carolina            NaN
# 614  70  2014           Ryan Grant  WR   10            Tulane  College Stats
# 615  71  2014        Jeremy Gallon  WR  NaN          Michigan  College Stats
# 616  72  2014      Austin Franklin  WR  NaN  New Mexico State  College Stats
# 617  73  2014        Bennie Fowler  WR    6    Michigan State  College Stats
# 618  74  2014      Shaquelle Evans  WR  NaN              UCLA  College Stats
# 619  75  2014           Mike Evans  WR   46         Texas A&M  College Stats
# 620  76  2014        Quincy Enunwa  WR   13          Nebraska  College Stats
# 621  77  2014      Bruce Ellington  WR    7    South Carolina  College Stats
# 622  78  2014           Mike Davis  WR  NaN             Texas  College Stats
# 623  79  2014      Damian Copeland  WR  NaN        Louisville  College Stats
# 624  80  2014        Brandin Cooks  WR   51      Oregon State  College Stats
# 625  81  2014          Kain Colter  WR  NaN      Northwestern  College Stats
# 626  82  2014      Brandon Coleman  WR   10           Rutgers  College Stats
# 627  83  2014    Michael Campanaro  WR    4       Wake Forest  College Stats
# 628  84  2014          Trey Burton  WR   10           Florida  College Stats
# 629  85  2014         Isaiah Burse  WR    0      Fresno State  College Stats
# 630  86  2014      Martavis Bryant  WR   20           Clemson  College Stats
# 631  87  2014          Corey Brown  WR   11        Ohio State  College Stats
# 632  88  2014           John Brown  WR   27   Pittsburg State            NaN
# 633  89  2014           Chris Boyd  WR  NaN        Vanderbilt  College Stats
# 634  90  2014      Kelvin Benjamin  WR   23     Florida State  College Stats
# 635  91  2014   Odell Beckham, Jr.  WR   45               LSU  College Stats
# 636  92  2014           Dri Archer  WR    0        Kent State  College Stats
# 637  93  2014        Davante Adams  WR   37      Fresno State  College Stats
# 638  94  2014     Jared Abbrederis  WR    1         Wisconsin  College Stats
#
#          HE Height   Wt  40YD Vertical BenchReps Broad Jump 3Cone Shuttle  \
# 0     4-Jun    6'4  320  5.22      NaN         9        NaN   NaN     NaN
# 1     6-Jun    6'6  318  5.27      NaN       NaN        NaN   NaN     NaN
# 2     7-Jun    6'7  315  5.46       25        22        105   7.9    4.81
# 3     4-Jun    6'4  313  5.44       21        23         94  8.23    5.07
# 4     5-Jun    6'5  310  5.29     24.5       NaN        103  8.31    5.01
# 5     3-Jun    6'3  300  5.06       30        24        107  7.77       5
# 6     2-Jun    6'2  317  5.49      NaN       NaN        110   NaN     NaN
# 7     3-Jun    6'3  332  5.58     22.5        28         96  7.78     5.1
# 8     6-Jun    6'6  308  5.17     31.5        20        101  7.94    4.91
# 9     4-Jun    6'4  307  5.09     29.5        29        109  7.48    4.69
# 10    3-Jun    6'3  320  5.11      NaN        27        NaN  7.45    4.63
# 11    5-Jun    6'5  306  5.08      NaN       NaN        NaN   NaN     NaN
# 12    5-Jun    6'5  302  5.08     29.5        25        112  7.49    4.45
# 13    4-Jun    6'4  307  5.12     28.5       NaN        103  7.45    4.63
# 14    4-Jun    6'4  306  4.95     30.5        32         97  7.71    4.56
# 15    6-Jun    6'6  321  5.23      NaN       NaN        NaN   NaN     NaN
# 16    5-Jun    6'5  316  5.37     28.5        20        101   8.1    4.88
# 17    4-Jun    6'4  314  5.14     28.5       NaN        104   NaN    4.87
# 18    8-Jun    6'8  315  5.34      NaN        31        NaN   NaN     NaN
# 19    2-Jun    6'2  317  5.48       23        35         95  8.07    4.82
# 20    6-Jun    6'6  313  4.91       28       NaN        107  7.83    4.63
# 21    4-Jun    6'4  317  5.13     22.5        23        105  7.72    4.65
# 22    5-Jun    6'5  331  5.49       22       NaN         88  8.06    5.06
# 23    6-Jun    6'6  303  4.72       34        28        118  7.31    4.52
# 24    5-Jun    6'5  313  5.37       23        17         92  8.12    4.74
# 25    6-Jun    6'6  306   5.3     28.5        27        106   7.4    4.68
# 26    4-Jun    6'4  320  5.25       28        36         95  7.99    5.09
# 27    5-Jun    6'5  298  5.07     28.5       NaN        112  7.52    4.51
# 28    6-Jun    6'6  318  5.29       30        28        108  7.65    4.75
# 29    6-Jun    6'6  334  5.24       23        28        NaN   NaN    5.24
# ..      ...    ...  ...   ...      ...       ...        ...   ...     ...
# 609   1-Jun    6'1  198  4.55       31        14        120  7.23     4.5
# 610  11-May   5'11  206  4.51     35.5        14        116   NaN     NaN
# 611   4-Jun    6'4  223  4.65     27.5        13        108  6.89     4.2
# 612   9-May    5'9  193  4.48     35.5        18        125  6.84    4.27
# 613   1-Jun    6'1  198   4.5     36.5        15        118  7.08     4.2
# 614  Jun-00    6'1  199  4.64     35.5         8        119  6.68    4.11
# 615   7-May    5'7  185  4.49      NaN        15        NaN   NaN     NaN
# 616  11-May   5'11  189  4.56       36         7        124  7.07    4.33
# 617   1-Jun    6'1  217  4.52       36       NaN        126  7.06    4.18
# 618   1-Jun    6'1  213  4.51     34.5        13        122  7.07    4.21
# 619   5-Jun    6'5  231  4.53       37        12        NaN  7.08    4.26
# 620   2-Jun    6'2  225  4.41      NaN        19        NaN   NaN     NaN
# 621   9-May    5'9  197  4.45     39.5        15        120  6.69    3.95
# 622  Jun-00    6'1  197  4.52      NaN        10        NaN   NaN     NaN
# 623  11-May   5'11  184   4.5       40        12        120  6.53     3.9
# 624  10-May   5'10  189  4.33       36        16        120  6.76    3.81
# 625  10-May   5'10  198  4.71      NaN       NaN        NaN   NaN     NaN
# 626   6-Jun    6'6  225  4.56     32.5        21        NaN  7.33    4.51
# 627   9-May    5'9  192  4.46       39        20        122  6.77    4.01
# 628   2-Jun    6'2  224  4.62       30       NaN        112  7.14    4.32
# 629  10-May   5'10  188  4.58       31        16        115  6.74    3.94
# 630   4-Jun    6'4  211  4.42       39        16        124  7.18    4.15
# 631  11-May   5'11  178  4.51       33       NaN        116  7.16    4.22
# 632  10-May   5'10  179  4.34     36.5       NaN        119  6.91    4.12
# 633   4-Jun    6'4  206  4.73      NaN        12        NaN   NaN     NaN
# 634   5-Jun    6'5  240  4.61     32.5        13        119  7.33    4.39
# 635  11-May   5'11  198  4.38     38.5         7        122  6.69    3.94
# 636   8-May    5'8  173  4.26       38        20        122  6.86    4.06
# 637   1-Jun    6'1  212  4.56     39.5        14        123  6.82     4.3
# 638   1-Jun    6'1  195   4.5     30.5         4        117   6.8    4.08
#
#                                 Drafted (tm/rnd/yr)
# 0            New York Jets / 3rd / 72nd pick / 2013
# 1           Houston Texans / 3rd / 89th pick / 2013
# 2                                               NaN
# 3                                               NaN
# 4          Oakland Raiders / 2nd / 42nd pick / 2013
# 5       Arizona Cardinals / 4th / 116th pick / 2013
# 6         Tennessee Titans / 1st / 10th pick / 2013
# 7            Detroit Lions / 3rd / 65th pick / 2013
# 8        Baltimore Ravens / 5th / 168th pick / 2013
# 9       Green Bay Packers / 4th / 122nd pick / 2013
# 10      Indianapolis Colts / 3rd / 86th pick / 2013
# 11          Miami Dolphins / 3rd / 77th pick / 2013
# 12         Houston Texans / 6th / 176th pick / 2013
# 13         New York Giants / 1st / 19th pick / 2013
# 14         Denver Broncos / 6th / 173rd pick / 2013
# 15                                              NaN
# 16          Chicago Bears / 5th / 163rd pick / 2013
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20           Chicago Bears / 1st / 20th pick / 2013
# 21      Carolina Panthers / 4th / 108th pick / 2013
# 22                                              NaN
# 23      Philadelphia Eagles / 1st / 4th pick / 2013
# 24                                              NaN
# 25     Jacksonville Jaguars / 1st / 2nd pick / 2013
# 26        New York Giants / 7th / 225th pick / 2013
# 27     Cincinnati Bengals / 5th / 156th pick / 2013
# 28       Cleveland Browns / 7th / 227th pick / 2013
# 29                                              NaN
# ..                                              ...
# 609                                             NaN
# 610    Philadelphia Eagles / 3rd / 86th pick / 2014
# 611                                             NaN
# 612  Tampa Bay Buccaneers / 6th / 185th pick / 2014
# 613        Miami Dolphins / 6th / 190th pick / 2014
# 614   Washington Redskins / 5th / 142nd pick / 2014
# 615  New England Patriots / 7th / 244th pick / 2014
# 616                                             NaN
# 617                                             NaN
# 618         New York Jets / 4th / 115th pick / 2014
# 619    Tampa Bay Buccaneers / 1st / 7th pick / 2014
# 620         New York Jets / 6th / 209th pick / 2014
# 621   San Francisco 49ers / 4th / 106th pick / 2014
# 622                                             NaN
# 623                                             NaN
# 624     New Orleans Saints / 1st / 20th pick / 2014
# 625                                             NaN
# 626                                             NaN
# 627      Baltimore Ravens / 7th / 218th pick / 2014
# 628                                             NaN
# 629                                             NaN
# 630   Pittsburgh Steelers / 4th / 118th pick / 2014
# 631                                             NaN
# 632      Arizona Cardinals / 3rd / 91st pick / 2014
# 633                                             NaN
# 634      Carolina Panthers / 1st / 28th pick / 2014
# 635        New York Giants / 1st / 12th pick / 2014
# 636    Pittsburgh Steelers / 3rd / 97th pick / 2014
# 637      Green Bay Packers / 2nd / 53rd pick / 2014
# 638     Green Bay Packers / 5th / 176th pick / 2014
#
# [639 rows x 17 columns]

# %%
import os
dirs = os.listdir( "./Resources" )

filenames = []
# This would print all the files and directories
for file in dirs:
  #print(file)
    filenames.append(file)

filenames
# Out:
# ['OL2010_2013.csv',
#  '.DS_Store',
#  'WR2010_2013.csv',
#  'WR2014_2015.csv',
#  'OL2014_2015.csv',
#  'TE2010_2015.csv']

# %%
combined_wrestlers_df['Pos'] = combined_wrestlers_df['Pos'].replace(
   {'OG': 'OL', 'OT': 'OL'})
combined_wrestlers_df.head()
# Out:
#    Rk  Year            Player Pos    AV          School        College     HE  \
# 0   1  2013     Brian Winters  OL  27.0      Kent State            NaN  4-Jun
# 1   2  2013  Brennan Williams  OL   NaN  North Carolina  College Stats  6-Jun
# 2   3  2013       John Wetzel  OL  11.0  Boston College            NaN  7-Jun
# 3   4  2013      Jason Weaver  OL   NaN   Southern Miss            NaN  4-Jun
# 4   5  2013    Menelik Watson  OL  12.0   Florida State            NaN  5-Jun
#
#   Height   Wt  40YD  Vertical  BenchReps  Broad Jump  3Cone  Shuttle  \
# 0    6'4  320  5.22       NaN        9.0         NaN    NaN      NaN
# 1    6'6  318  5.27       NaN        NaN         NaN    NaN      NaN
# 2    6'7  315  5.46      25.0       22.0       105.0   7.90     4.81
# 3    6'4  313  5.44      21.0       23.0        94.0   8.23     5.07
# 4    6'5  310  5.29      24.5        NaN       103.0   8.31     5.01
#
#                         Drafted (tm/rnd/yr)
# 0    New York Jets / 3rd / 72nd pick / 2013
# 1   Houston Texans / 3rd / 89th pick / 2013
# 2                                       NaN
# 3                                       NaN
# 4  Oakland Raiders / 2nd / 42nd pick / 2013
